# %% [markdown]
# # Prompting with Gemini
# Notebook for experimenting different promting techniques with Gemini

# %% [markdown]
# Install the required dependencies with the following command.

# %%
# %pip install google-generativeai
# Out:
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.12/dist-packages (0.8.5)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.28.1)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.187.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.43.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.12.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (4.15.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core->google-generativeai) (1.72.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.12/dist-packages (from google-api-core->google-generativeai) (2.32.4)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (0.31.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (0.2.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (0.4.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /usr/local/lib/python3.12/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2025.11.12)

# %% [markdown]
# Import the required libraries.

# %%
import google.generativeai as genai
import os
# from google.colab import userdata # uncomment and use in colab

# %% [markdown]
# Insert your Gemini API key to the following command and import the Gemini model.

# %%
API_KEY="AIzaSyBkbw4C6gQDVNJzv8WHmP2ICfwYD62RiVQ" # Add you API key here
# API_KEY = userdata.get('GEMINI_API_KEY') # uncomment and use this in Google Colab
genai.configure(api_key=API_KEY)

model = genai.GenerativeModel('gemini-2.5-flash')

# %% [markdown]
# Modify the `system_prompt` to experiment with different prompting approaches. (Zero-shot Prompt)

# %%
system_prompt = """请生成一份关于“可乐鸡翅”的食谱。"""

# %% [markdown]
# We create a list of messages so that we keep history in the context. If you want to clear the messages later in this notebook, add the line `messages = []` to a new line cell in the notebook.

# %%
messages = []
messages.append(system_prompt)

# %% [markdown]
# Get the response from Gemini model by providing the prompt in a messages list to it.

# %%
r = model.generate_content(messages).text

# %% [markdown]
# Print the output of the model.

# %%
print(r)
# Out:
# 好的，这里为您奉上一份详尽的“可乐鸡翅”食谱，制作简单，味道鲜甜，大人小孩都爱！
#
# ---
#
# ## **经典家常美味：可乐鸡翅**
#
# 可乐鸡翅是一道备受欢迎的家常菜，做法简单，色泽红亮诱人，鸡肉软嫩入味，带着可乐独特的焦糖香甜，让人回味无穷。
#
# ---
#
# ### **【食材准备】**
#
# *   **主料：**
#     *   鸡翅中：约500克-700克（约10-12个）
# *   **辅料及调味料：**
#     *   可乐：1罐（约330ml-350ml，普通含糖可乐最佳）
#     *   生抽（Light Soy Sauce）：2汤匙
#     *   老抽（Dark Soy Sauce）：1汤匙（主要用于上色）
#     *   料酒（Cooking Wine）：1汤匙
#     *   姜：几片
#     *   蒜：3-4瓣（拍扁或切片）
#     *   食用油：适量
#     *   盐：适量（焯水用及最后调味）
#     *   葱花：适量（点缀用）
#     *   **可选香料：** 八角（1-2个）、干辣椒（2-3个，喜欢微辣可放）
#
# ---
#
# ### **【制作步骤】**
#
# 1.  **鸡翅初处理：**
#     *   将鸡翅中用清水冲洗干净。
#     *   为了更好地入味，用刀在每个鸡翅两面斜划2-3刀，或用牙签在鸡翅上扎些小孔。
#     *   将鸡翅放入碗中，加入1汤匙料酒和少许姜片，抓匀腌制10-15分钟，帮助去腥。
#
# 2.  **鸡翅焯水：**
#     *   锅中放入足量冷水，加入腌制好的鸡翅和另外几片姜，大火煮开。
#     *   水开后，撇去浮沫，继续煮2-3分钟。
#     *   捞出鸡翅，用温水冲洗干净表面的浮沫，沥干水分备用（这一步很重要，可以去除血水和腥味）。
#
# 3.  **煎制上色：**
#     *   锅中倒入适量食用油，烧至六成热。
#     *   将沥干水分的鸡翅放入锅中，中小火煎至两面金黄。这一步能锁住鸡肉的水分，使口感更香，也能让鸡皮更完整。
#
# 4.  **爆香调味：**
#     *   将煎好的鸡翅拨到锅边，放入姜片、蒜瓣（如果放八角和干辣椒也一同放入），煸炒出香味。
#     *   倒入2汤匙生抽和1汤匙老抽，快速翻炒，让鸡翅均匀裹上酱油的颜色。
#
# 5.  **可乐焖煮：**
#     *   倒入整罐可乐，可乐的量要没过鸡翅一半或全部（如果不够可加少量开水补足，但尽量用可乐）。
#     *   大火煮开后，转中小火，盖上锅盖焖煮15-20分钟，直到鸡翅熟透入味。
#
# 6.  **大火收汁：**
#     *   开盖，转大火收汁。在收汁过程中，要不断翻动鸡翅，防止粘锅，并让每块鸡翅都均匀裹上浓稠的汤汁。
#     *   待汤汁变得浓稠、红亮，并紧紧地包裹在鸡翅上时，即可关火。尝一下味道，如果觉得不够咸可以加少量盐调味。
#
# 7.  **装盘享用：**
#     *   将煮好的可乐鸡翅盛出装盘，撒上葱花点缀，即可趁热享用。
#
# ---
#
# ### **【小贴士】**
#
# 1.  **关于可乐：** 建议使用普通含糖可乐，其糖分和风味是这道菜的灵魂。无糖可乐做出来的效果会差一些，可能需要额外加糖来弥补甜度。
# 2.  **鸡翅划刀/扎孔：** 这一步能让鸡翅更易入味，缩短烹饪时间。
# 3.  **焯水：** 冷水下锅焯水能更好地逼出鸡翅中的血沫和腥味，是去腥的关键一步。焯水后一定要用温水冲洗，防止鸡肉遇冷收缩影响口感。
# 4.  **煎制：** 提前煎一下鸡翅可以使鸡皮更紧实，口感更好，也能防止在炖煮过程中鸡皮破损。
# 5.  **收汁：** 收汁是可乐鸡翅的精髓，决定了这道菜的色泽和口感。一定要将汤汁收浓稠，包裹在鸡翅上，这样才能达到“红亮、黏糯”的效果。
# 6.  **口味调整：** 喜欢甜味更浓的可以在收汁前加一小勺糖，喜欢辣味的可以在爆香时多放些干辣椒。
#
# ---
#
# 希望您享受制作和品尝这道美味的可乐鸡翅！

# %% [markdown]
# Let's define a new prompt. (Few-shot Prompt)

# %%
user_input = """
示例：菜肴：麻婆豆腐
食材：豆腐，肉末，干辣椒
步骤：1. 翻炒肉末和辣椒。2. 加入豆腐和酱汁，炖煮 5 分钟。
任务：现在请按照完全相同的格式生成一份“可乐鸡翅”的食谱。
"""

# %% [markdown]
# *Let*'s add a the new prompt to the messages list.

# %%
messages.append(user_input)

# %% [markdown]
# Again we generate the output with the Gemini model.

# %%
r = model.generate_content(messages).text

# %% [markdown]
# ... and print the output.

# %%
print(r)
# Out:
# 菜肴：可乐鸡翅
# 食材：鸡翅，可乐，姜，蒜，生抽，老抽，料酒
# 步骤：1. 鸡翅焯水后，热锅炒香姜蒜，放入鸡翅煎至两面金黄。2. 加入可乐、生抽、老抽和料酒，大火烧开转小火炖煮至汤汁浓稠即可。

# %% [markdown]
# Let's define a new prompt. (Chain-of-Thought Prompt)

# %%
prompt_cot = """
请一步一步地思考：
1. 制作“可乐鸡翅”需要哪些食材？
2. 应该如何准备和烹饪？
3. 最后，请将食谱以清晰的“食材”和“步骤”部分写出。
"""
messages.append(prompt_cot)
r = model.generate_content(messages).text
print(r)
# Out:
# 菜肴：可乐鸡翅
# 食材：鸡翅，可乐，生抽，料酒，姜，蒜，食用油
# 步骤：1. 鸡翅洗净划刀，用少量油煎至两面金黄，加入姜蒜炒香。
# 2. 倒入料酒、生抽翻炒，接着加入可乐，大火烧开。
# 3. 转小火炖煮15-20分钟，待汤汁浓稠后大火收汁。

# %% [markdown]
# Let's define a new prompt. (Prompt Chaining)

# %%
prompt_stage1 = "列出制作“可乐鸡翅”所需要的全部食材。"

messages = []
messages.append(prompt_stage1)

ingredients = model.generate_content(messages).text
print("===== Ingredients =====")
print(ingredients)
# Out:
# ===== Ingredients =====
# 制作“可乐鸡翅”所需的食材非常简单，主要分为主料、调料和香料几部分：
#
# **主料：**
#
# *   **鸡中翅或全翅：** 500-750克 (约1-1.5磅)，建议使用中翅，更容易入味和烹饪。
# *   **普通可乐：** 300-500毫升 (约一罐或一小瓶)，**务必使用含糖的普通可乐，非无糖可乐。**
#
# **调料：**
#
# *   **生抽 (Light Soy Sauce)：** 2-3汤匙 (用于提鲜和咸味)
# *   **老抽 (Dark Soy Sauce)：** 1/2-1汤匙 (用于上色，使鸡翅颜色红亮)
# *   **料酒 (Cooking Wine)：** 1-2汤匙 (用于去腥)
# *   **冰糖 (Rock Sugar)：** 5-10克 (或少量白砂糖，用于增加甜度和光泽，帮助上色)
# *   **盐：** 适量 (根据口味调整，生抽已有咸味，可能无需额外添加或少量)
# *   **食用油：** 适量 (用于煎鸡翅)
#
# **香料/辅料：**
#
# *   **姜：** 2-3片 或 几片姜片 (用于去腥增香)
# *   **蒜：** 2-3瓣 或 几瓣蒜头 (拍扁或切片)
# *   **葱：** 1-2根 (切段，一部分用于烹饪，一部分可切葱花用于最后装饰)
#
# **可选香料/装饰：**
#
# *   **干辣椒：** 1-2个 (如果喜欢微辣口味，可加入)
# *   **八角：** 1个 (增加复合香气，如果喜欢更浓郁的卤味香气)
# *   **白芝麻：** 少许 (出锅后撒在鸡翅上，用于装饰和增加风味)
#
# **总结：**
#
# 核心食材是 **鸡翅** 和 **普通可乐**，配以 **生抽、老抽、姜、蒜** 即可制作出基本的可乐鸡翅。其他调料可根据个人口味偏好增减。

# %%
prompt_stage2 = f"""
根据以下食材列表（*   **鸡翅中**
*   **可乐**
*   **生抽**
*   **老抽**
*   **料酒**
*   **盐**
*   **白胡椒粉 (可选)**
*   **冰糖 (可选)**
*   **姜**
*   **蒜**
*   **葱**
*   **食用油**
*   **八角 (可选)**
*   **干辣椒 (可选)**），撰写一份详细的“可乐鸡翅”食谱，包含完整的烹饪步骤。
"""

messages = []
messages.append(prompt_stage2)

r_chain = model.generate_content(messages).text
print("===== Final Recipe =====")
print(r_chain)
# Out:
# ===== Final Recipe =====
# 好的，根据您提供的食材列表，为您精心撰写一份详细的“可乐鸡翅”食谱。这道菜制作简单，味道甜咸适口，是大人小孩都爱的一道家常菜。
#
# ---
#
# ### 经典家常可乐鸡翅
#
# **简介：**
# 可乐鸡翅是一道风靡大江南北的家常菜，以鸡翅为主料，搭配可乐和其他调味料烹制而成。可乐独特的焦糖甜味与鸡肉的鲜美完美融合，形成甜咸交织、色泽红亮、汁浓味厚的诱人风味。本食谱力求步骤清晰，让您在家也能轻松做出美味又地道的可乐鸡翅。
#
# **烹饪时间：**
# *   准备时间：15-20分钟 (含腌制)
# *   烹饪时间：25-35分钟
# *   总计：40-55分钟
#
# **份量：** 2-3人份
#
# ---
#
# **一、所需食材：**
#
# *   **主料：**
#     *   鸡翅中：500克 (约10-12个)
#     *   可乐：300-400毫升 (以能基本没过鸡翅为准，建议使用原味可乐，非无糖或零度可乐)
#
# *   **腌制/去腥：**
#     *   料酒：1汤匙 (约15毫升)
#     *   生抽：1汤匙 (约15毫升)
#     *   姜：2-3片
#     *   白胡椒粉：少许 (可选，用于去腥增香)
#     *   盐：少许 (可选，腌制用，也可不加，主要靠后续调味)
#
# *   **调味料：**
#     *   生抽：2汤匙 (约30毫升)
#     *   老抽：1茶匙 (约5毫升，用于上色)
#     *   料酒：1汤匙 (约15毫升)
#     *   盐：适量 (根据口味调整，可乐和生抽本身有咸味)
#     *   冰糖：5-8小块 或 1汤匙 (可选，增添风味和亮泽)
#
# *   **香料/辅料：**
#     *   姜：4-5片
#     *   蒜：3-4瓣 (拍扁或切片)
#     *   葱：2段 (葱白和葱绿分开)
#     *   食用油：适量
#     *   八角：1-2颗 (可选，增加复合香气)
#     *   干辣椒：1-2个 (可选，增加微辣风味)
#
# ---
#
# **二、详细烹饪步骤：**
#
# **第一步：鸡翅预处理**
# 1.  **清洗与划刀：** 将鸡翅中清洗干净，沥干水分。为了让鸡翅更入味，在每个鸡翅两面斜划2-3刀 (深度至骨，不要切断)。
# 2.  **焯水 (可选，推荐)：** 锅中加足量冷水，放入鸡翅、2-3片姜、1汤匙料酒。大火烧开后，撇去浮沫，继续煮2-3分钟。捞出鸡翅用温水冲洗干净，沥干备用。*(焯水可以去除鸡翅的血沫和腥味，使成品口感更清爽。)*
# 3.  **腌制：** 将处理好的鸡翅放入碗中，加入1汤匙料酒、1汤匙生抽、少许白胡椒粉（可选）、2-3片姜。用手抓匀，腌制15-20分钟，让其初步入味。
#
# **第二步：准备辅料**
# 1.  姜切片，蒜拍扁或切片。
# 2.  葱白切段，葱绿切葱花备用。
# 3.  如果使用八角和干辣椒，也一并准备好。
#
# **第三步：煸炒鸡翅与爆香**
# 1.  锅中倒入适量食用油，烧至六成热。
# 2.  放入腌制好的鸡翅，中火煎至两面金黄。这一步是为了锁住鸡翅的水分，使口感更Q弹，并增添焦香风味。
# 3.  将煎好的鸡翅拨到锅的一边，放入姜片、蒜瓣、葱白段、八角、干辣椒（可选），煸炒出香味。
#
# **第四步：调味与炖煮**
# 1.  待香料爆香后，将鸡翅与香料混合，加入2汤匙生抽、1茶匙老抽、1汤匙料酒，翻炒均匀，使鸡翅上色。
# 2.  倒入可乐，液面应基本没过鸡翅。如果觉得可乐不够，可以适量加一点点清水。
# 3.  加入冰糖（可选），轻轻搅拌，使冰糖融化。
# 4.  大火烧开后，转小火，盖上锅盖，炖煮15-20分钟，让鸡翅充分吸收汤汁的味道。
#
# **第五步：收汁与出锅**
# 1.  15-20分钟后，打开锅盖，尝一下汤汁的味道，根据个人喜好调整咸度（如果不够咸可以加少许盐）。
# 2.  转大火，敞开锅盖，不断翻炒，将汤汁收浓。这一步是关键，汤汁会变得浓稠，紧紧包裹在鸡翅上，形成诱人的琥珀色光泽。
# 3.  待汤汁变得浓稠，呈亮晶晶的酱汁状态时，即可关火。
# 4.  将可乐鸡翅盛出，撒上提前准备好的葱花，即可享用。
#
# ---
#
# **三、小贴士：**
#
# 1.  **可乐选择：** 强烈建议使用原味含糖可乐，不要使用无糖或零度可乐，因为其中的甜味剂在加热后口感会有变化，也无法提供可乐应有的焦糖风味和色泽。
# 2.  **划刀入味：** 在鸡翅上划刀非常重要，能大大缩短腌制和烹饪时间，使鸡翅更加入味。
# 3.  **冰糖作用：** 冰糖是可乐鸡翅的灵魂伴侣之一，它不仅能增加甜味，还能让汤汁更加浓稠，使鸡翅表面形成一层晶亮诱人的焦糖色泽。
# 4.  **火候控制：** 煸炒鸡翅时中火即可，以免外焦内生。炖煮时转小火，让鸡翅慢慢入味。最后收汁时转大火，快速收浓，但要不断翻动，防止糊底。
# 5.  **调味灵活：** 食谱中的调料用量是参考值，请根据个人口味调整。可乐本身有甜度，冰糖可以酌情添加。老抽主要是上色，用量不宜过多，否则颜色会过深。
# 6.  **去腥：** 除了焯水，腌制时的料酒、姜片和白胡椒粉也都有很好的去腥效果。
#
# ---
#
# 希望这份详细的食谱能帮助您轻松做出美味可口的可乐鸡翅！享受烹饪的乐趣吧！

# %% [markdown]
# Let's define a new prompt. (Tree-of-Thought (ToT) Prompt)

# %%
prompt_tot = """
请以 ’可乐鸡翅’ 为主题，执行以下任务：
1. **生成多条路径/方案：**提出至少三种不同的烹饪“可乐鸡翅”的关键方法或配料组合（例如：先焯水 vs 不焯水；只用可乐 vs 可乐+啤酒；是否使用老抽上色）。
2. **评估：**分析每种方案的优缺点（例如：口感、颜色、耗时、难度）。
3. **精选：**基于评估结果，选择并撰写一个你认为最佳的、最详细的“可乐鸡翅”完整食谱。
"""
messages.append(prompt_tot)
r = model.generate_content(messages).text
print(r)
# Out:
# “可乐鸡翅”是深受大众喜爱的一道家常菜，集甜、咸、鲜于一身，色泽红亮诱人。它的制作方法多样，不同处理方式会带来不同的风味和视觉效果。下面我将为您分析几种烹饪方案，并精选一份我个人认为最佳的详细食谱。
#
# ---
#
# ### **任务一：生成多条路径/方案**
#
# 以下是制作“可乐鸡翅”的至少三种关键方法或配料组合：
#
# **方案一：懒人快手版（极简主义）**
# *   **关键特点:** 不焯水，不腌制（或极简单腌制），不加冰糖和过多香料（仅姜蒜）。主要依靠可乐、生抽和鸡翅本身的油脂来完成。
# *   **目标:** 快速、方便、突出可乐的甜味。
#
# **方案二：经典浓郁版（均衡风味）**
# *   **关键特点:** 焯水去腥，先煎后炖，使用生抽、老抽调味上色，加入冰糖增亮提味，并使用姜、蒜、八角、干辣椒等多种香料增添层次感。
# *   **目标:** 色泽红亮，味道醇厚，鸡肉软烂入味，酱汁浓稠。
#
# **方案三：先腌后煎版（入味嫩滑）**
# *   **关键特点:** 提前将鸡翅用料酒、生抽、姜片等腌制，不焯水，直接煎至金黄后再加入可乐和调料炖煮。可酌情添加冰糖和少量老抽。
# *   **目标:** 鸡肉更加入味，口感更嫩滑，同时有煎炸带来的焦香。
#
# ---
#
# ### **任务二：评估**
#
# 对以上三种方案进行优缺点分析：
#
# **方案一：懒人快手版**
#
# *   **优点:**
#     *   **耗时短/难度低:** 步骤最少，省略焯水和复杂香料，适合新手和时间紧张者。
#     *   **操作简单:** 对厨艺要求低，基本零失败。
#     *   **突出可乐原味:** 甜味和焦糖味更直接。
# *   **缺点:**
#     *   **颜色偏淡:** 缺少老抽和冰糖的加持，颜色可能不够诱人。
#     *   **风味单一:** 缺乏香料的层次感，味道可能略显平淡。
#     *   **去腥不够彻底:** 不焯水，鸡肉的腥味可能处理不彻底（虽说炸过可以改善）。
#     *   **肉质口感:** 不易达到非常软糯的效果。
#
# **方案二：经典浓郁版**
#
# *   **优点:**
#     *   **色泽红亮:** 焯水后更容易上色，老抽和冰糖使得成品颜色诱人，有光泽。
#     *   **风味层次丰富:** 香料（姜蒜葱八角干辣椒）与可乐、酱油结合，味道更饱满有深度。
#     *   **去腥彻底:** 焯水能有效去除血沫和腥味，使得口感更纯净。
#     *   **肉质软烂入味:** 经过炖煮和充分收汁，鸡肉嫩滑入味，酱汁浓稠包裹。
#     *   **卖相佳:** 成品色香味俱全，更接近餐厅水平。
# *   **缺点:**
#     *   **耗时较长:** 焯水、煸炒、炖煮步骤较多，整体烹饪时间稍长。
#     *   **操作步骤较多:** 对新手来说可能稍微复杂一点，但掌握后并非难事。
#
# **方案三：先腌后煎版**
#
# *   **优点:**
#     *   **鸡肉更入味:** 提前腌制使鸡肉内部更加入味，肉质更嫩滑。
#     *   **外焦里嫩:** 煎制后有很好的焦糖色和外皮口感。
#     *   **香气浓郁:** 腌料中的姜蒜香气能很好地渗透到鸡肉中。
# *   **缺点:**
#     *   **额外耗时:** 腌制通常需要至少30分钟到1小时。
#     *   **颜色控制:** 如果不加老抽，颜色可能不够深，不如方案二红亮。
#     *   **去腥效果:** 不焯水，去腥效果不如方案二彻底，依赖腌制和香料压制。
#
# ---
#
# ### **任务三：精选并撰写食谱**
#
# 基于以上评估，我推荐选择 **方案二：经典浓郁版**。虽然步骤略多，但它在色泽、风味和口感上达到了最佳平衡，成品最能体现可乐鸡翅的经典魅力，也更适合宴客或与家人分享。
#
# ---
#
# ## **可乐鸡翅（经典浓郁版）**
#
# 这道经典的可乐鸡翅，不仅色泽红亮诱人，味道也甜咸适中，香料的加入让风味更加醇厚有层次。经过焯水和先煎后炖，鸡翅外皮Q弹，肉质软烂入味，酱汁浓稠地包裹着每一块鸡翅，是米饭的最佳拍档！
#
# ### **【食材清单】**
#
# *   **主料:**
#     *   鸡翅中：约500克 (约10-12个)
# *   **调料:**
#     *   可乐：约300-350毫升 (一罐小听可乐即可，或一瓶大可乐的一半，以能没过鸡翅2/3为宜)
#     *   生抽：2汤匙 (约30毫升，提鲜咸味)
#     *   老抽：1汤匙 (约15毫升，上色用，可根据喜好调整)
#     *   料酒：2汤匙 (约30毫升，去腥增香，焯水和烹饪各1汤匙)
#     *   盐：适量 (最后尝味调整)
#     *   白胡椒粉：少许 (可选，腌制用，去腥增香)
#     *   冰糖：5-8粒 (或10-15克，可选，提亮增色，增加醇厚感)
# *   **香料与配料:**
#     *   姜：4-5片 (或一小块切片)
#     *   蒜：3-4瓣 (切片)
#     *   葱：1段 (切葱花或葱段，用于点缀和提香)
#     *   食用油：适量 (用于煎鸡翅)
#     *   八角：1-2个 (可选，增加复合香气)
#     *   干辣椒：2-3个 (可选，增加微辣风味，不喜辣可不放)
#
# ### **【烹饪步骤】**
#
# 1.  **鸡翅初步处理与腌制：**
#     *   将鸡翅中清洗干净，用厨房纸巾吸干表面水分。
#     *   在每个鸡翅两面划2-3刀，方便入味和快速成熟。
#     *   将处理好的鸡翅放入大碗中，加入1汤匙料酒、2-3片姜片和少许白胡椒粉（可选），抓匀腌制15-20分钟，帮助去腥。
#
# 2.  **鸡翅焯水：**
#     *   锅中烧水，水开后放入腌制好的鸡翅，加入另外1汤匙料酒，撇去浮沫。
#     *   焯水约2-3分钟，待鸡翅变色、血沫出尽后捞出。
#     *   用温水（或流动清水）冲洗掉鸡翅表面的浮沫和杂质，再次沥干水分备用。这一步是去除腥味和让鸡翅颜色更红亮的关键。
#
# 3.  **准备配料：**
#     *   姜切片，蒜切片，葱切葱花（或切段备用）。
#     *   八角和干辣椒准备好。
#
# 4.  **煎制鸡翅上色：**
#     *   热锅倒入适量食用油，油热后放入沥干水分的鸡翅中。
#     *   中小火慢煎，将鸡翅两面煎至金黄，表皮略带焦色，这样能锁住水分，增加香气，并使后续更容易上色。
#
# 5.  **爆香调料：**
#     *   将煎好的鸡翅拨到锅边，利用锅中余油，放入姜片、蒜片、八角和干辣椒（如果使用）爆香。
#     *   炒出香味后，将香料与鸡翅一同翻炒均匀。
#
# 6.  **调味上色：**
#     *   沿着锅边淋入1汤匙料酒，炒出酒香味。
#     *   接着倒入生抽和老抽，快速翻炒，让鸡翅均匀裹上酱汁，尤其是老抽可以给鸡翅带来诱人的红亮色泽。
#     *   如果使用冰糖，此时放入冰糖粒，翻炒至冰糖融化，给鸡翅增添光泽和更丰富的甜味。
#
# 7.  **倒入可乐炖煮：**
#     *   倒入可乐，可乐的量以能基本没过鸡翅2/3为宜，不用完全没过。
#     *   大火烧开后，转小火，盖上锅盖，焖煮约15-20分钟，让鸡翅充分吸收汤汁，变得软烂入味。
#
# 8.  **大火收汁：**
#     *   打开锅盖，转大火，开始收汁。
#     *   在收汁过程中，要不停地用铲子翻动鸡翅，防止糊底，并让每个鸡翅都均匀裹上浓稠的酱汁。
#     *   待汤汁变得浓稠，能均匀地挂在鸡翅上，并呈现出油亮的光泽时，即可关火。
#
# 9.  **出锅装盘：**
#     *   将可乐鸡翅盛出装盘，撒上葱花点缀即可。趁热食用风味最佳！
#
# ### **【小贴士】**
#
# *   **可乐选择：** 建议使用普通含糖可乐，无糖可乐会影响风味和色泽。
# *   **鸡翅划刀：** 一定要划刀，不仅能让鸡翅更快速入味，也能缩短烹饪时间。
# *   **焯水要彻底：** 焯水是去腥的关键一步，不要省略。焯水后用温水冲洗，避免热胀冷缩影响肉质。
# *   **老抽用量：** 老抽主要是上色，少量多次添加，避免颜色过深发黑。
# *   **收汁是关键：** 大火收汁能让酱汁变得浓稠，更好地包裹鸡翅，提升口感和卖相。收汁时一定要不停翻炒，避免糊锅。
# *   **盐的调整：** 生抽和老抽都有咸味，冰糖也有甜味，所以盐可以在最后尝味后酌情添加，避免过咸。

# %% [markdown]
# Let's define a new prompt. (In-context Learning Prompt)

# %%
prompt_icl = """
食谱示例：菜肴：红烧肉
食材：五花肉、酱油、白糖
步骤：1. 将五花肉焯水。2. 用酱油和白糖煨煮至软烂入味。
任务：现在，请遵循相同的风格和语气，撰写一份“可乐鸡翅”的食谱。
"""
messages.append(prompt_icl)
r = model.generate_content(messages).text
print(r)
# Out:
# 好的，我们来为“可乐鸡翅”制定一份详细的烹饪方案。
#
# ---
#
# ## 可乐鸡翅
#
# 可乐鸡翅是一道家喻户晓的家常菜，以其独特的甜咸口味和油亮诱人的色泽深受喜爱。它融合了可乐的焦糖香甜与酱油的醇厚鲜美，使鸡翅软烂入味，外皮Q弹。
#
# ### 1. 多条路径/方案探讨
#
# **方案一：极简快手版 (不焯水，少调料)**
#
# *   **核心思路：** 省略焯水步骤，直接将鸡翅煎香后，加入可乐和基础调料焖煮。
# *   **关键方法：**
#     1.  鸡翅洗净划刀，用少许料酒和姜片腌制去腥。
#     2.  锅中放油，将鸡翅两面煎至金黄。
#     3.  加入姜蒜、生抽、老抽、可乐，大火烧开转小火焖煮，最后大火收汁。
# *   **配料组合：** 鸡翅中、可乐、生抽、老抽、料酒、姜、蒜、食用油、盐（可选）。
#
# **方案二：经典平衡版 (焯水，标准调味，注重色泽)**
#
# *   **核心思路：** 焯水去除腥味和血沫，确保鸡翅口感更干净；通过老抽上色，并利用冰糖增加光泽和风味层次。
# *   **关键方法：**
#     1.  鸡翅焯水，用姜片、料酒辅助去腥。
#     2.  煎至金黄，加入姜蒜爆香。
#     3.  加入生抽、老抽、料酒、可乐、冰糖、八角（可选）焖煮，收汁。
# *   **配料组合：** 鸡翅中、可乐、生抽、老抽、料酒、盐（可选）、白胡椒粉（可选）、冰糖、姜、蒜、葱、食用油、八角（可选）。
#
# **方案三：风味增强版 (焯水，先炒糖色，加入香料提味)**
#
# *   **核心思路：** 在经典版基础上，先炒糖色为鸡翅打底色，并加入八角、干辣椒等香料，使味道更复合、更浓郁。
# *   **关键方法：**
#     1.  鸡翅焯水并腌制。
#     2.  锅中放油，小火融化冰糖炒出糖色，放入鸡翅上色。
#     3.  加入姜蒜、八角、干辣椒爆香。
#     4.  倒入生抽、老抽、料酒、可乐，焖煮收汁。
# *   **配料组合：** 鸡翅中、可乐、生抽、老抽、料酒、盐（可选）、白胡椒粉（可选）、冰糖、姜、蒜、葱、食用油、八角、干辣椒。
#
# ---
#
# ### 2. 评估每种方案的优缺点
#
# **方案一：极简快手版**
#
# *   **优点：**
#     *   **耗时：** 最短，省去了焯水的时间。
#     *   **难度：** 最低，操作步骤最简单。
#     *   **口感：** 保留了鸡翅本身更多的原汁原味，可乐味道更突出。
# *   **缺点：**
#     *   **颜色：** 可能不够红亮，全靠老抽上色，容易颜色不均匀。
#     *   **口感：** 如果鸡翅处理不好，可能会有轻微腥味；酱汁可能不够浓郁。
#     *   **风味：** 层次感较少，相对单一。
#
# **方案二：经典平衡版**
#
# *   **优点：**
#     *   **口感：** 焯水后鸡翅更干净，无腥味，肉质更紧实。冰糖和可乐的甜味平衡，酱汁浓郁。
#     *   **颜色：** 老抽和冰糖的结合，使得鸡翅颜色红亮诱人，色泽均匀。
#     *   **耗时：** 适中，比快手版略长但效果更好。
#     *   **难度：** 中等，适合大多数家庭操作。
# *   **缺点：**
#     *   **风味：** 相对于风味增强版，香料的层次感略少。
#
# **方案三：风味增强版**
#
# *   **优点：**
#     *   **风味：** 最丰富，糖色能赋予更深的焦糖香气，八角和干辣椒则增加了复合的香辣味道，回味悠长。
#     *   **颜色：** 炒糖色后上色更均匀，颜色深邃诱人。
#     *   **口感：** 酱汁最浓稠，鸡翅包裹着浓郁的酱汁，味道更足。
# *   **缺点：**
#     *   **耗时：** 最长，炒糖色需要一定的技巧和时间。
#     *   **难度：** 最高，炒糖色需要把握火候，以免炒糊发苦；香料的用量也需平衡。
#     *   **口味：** 对于不喜欢复杂香料或微辣口味的人来说，可能不适合。
#
# ---
#
# ### 3. 精选最佳食谱
#
# 综合评估，**方案二“经典平衡版”**在口感、色泽、耗时和难度之间取得了最佳平衡。它既能保证菜品的干净美味和诱人色泽，又不会过于繁琐或挑战厨艺，非常适合家庭烹饪。
#
# ---
#
# ## 可乐鸡翅 (经典平衡版)
#
# 这份食谱注重鸡翅的干净口感、诱人色泽和均衡的甜咸风味，是家庭制作可乐鸡翅的经典之选。
#
# ### 食材：
#
# *   **鸡翅中：** 500克 (约10-12个)
# *   **可乐：** 300-350毫升 (约一听半，能基本没过鸡翅的量)
# *   **生抽：** 2汤匙 (30毫升)
# *   **老抽：** 1茶匙 (5毫升，主要用于上色)
# *   **料酒：** 2汤匙 (30毫升，用于焯水和烹饪去腥)
# *   **盐：** 1/4茶匙 (或适量，根据口味调整)
# *   **白胡椒粉：** 少量 (可选，用于腌制去腥)
# *   **冰糖：** 5-8颗小块 (约15-20克，可让颜色更亮，味道更醇厚)
# *   **姜：** 5-6片 (用于焯水和爆香)
# *   **蒜：** 3-4瓣 (拍扁或切片)
# *   **葱：** 1-2段 (白色部分用于焯水和爆香，绿色部分切葱花做点缀)
# *   **食用油：** 适量
# *   **八角：** 1-2个 (可选，增加香气)
#
# ### 烹饪步骤：
#
# 1.  **鸡翅初步处理：**
#     *   将鸡翅中洗净，沥干水分。
#     *   在每个鸡翅两面用刀划2-3刀，以便更好地入味。
#     *   将处理好的鸡翅放入碗中，加入1汤匙料酒、少量白胡椒粉和2片姜片，抓匀腌制10-15分钟去腥。
#
# 2.  **鸡翅焯水：**
#     *   锅中加入足量冷水，放入腌制好的鸡翅、2片姜片和1汤匙料酒。
#     *   开大火煮沸，煮沸后撇去浮沫。
#     *   继续煮2-3分钟，直到鸡翅颜色变白，去除血水和腥味。
#     *   捞出鸡翅，用温水冲洗干净浮沫，沥干水分备用。
#
# 3.  **煎香鸡翅：**
#     *   炒锅烧热，倒入适量食用油，油热后放入沥干水分的鸡翅。
#     *   用中小火将鸡翅两面煎至金黄，表皮略焦，这样能锁住鸡翅的水分，并增加焦香味。煎好后盛出备用。
#
# 4.  **爆香调料：**
#     *   无需洗锅，直接在锅中留少量底油。
#     *   放入剩余的姜片、蒜片和葱白段（如果用八角，此时一同放入），小火煸炒出香味。
#
# 5.  **调味与焖煮：**
#     *   将煎好的鸡翅倒回锅中，翻炒均匀。
#     *   倒入生抽、老抽，翻炒至鸡翅均匀上色。
#     *   加入冰糖，倒入可乐，可乐的量要基本没过鸡翅。
#     *   大火烧开后，转小火，盖上锅盖，焖煮15-20分钟，直到鸡翅熟透并入味。
#
# 6.  **收汁提亮：**
#     *   打开锅盖，尝一下汤汁味道，根据个人口味适量加入盐调整咸淡。
#     *   转大火，开始收汁。在收汁过程中，要不断翻动鸡翅，让其均匀裹上浓稠的酱汁，防止糊底。
#     *   待汤汁变得浓稠、油亮，能均匀地挂在鸡翅上时，即可关火。
#
# 7.  **盛盘享用：**
#     *   将可乐鸡翅盛入盘中，撒上切好的葱花做点缀即可。
#
# ---

# %% [markdown]
# Let's define a new prompt. (Prompt Templates)

# %%
prompt_pt = """
你是一位专业大厨。请根据以下信息，生成一个详细的食谱。食谱生成请求
菜肴名称 (Dish Name)：可乐鸡翅
风味要求 (Flavor Profile)：甜咸适中，鸡翅软嫩，色泽红亮
输出格式 (Output Format)：必须包含「主食材」、「配料」和「步骤」三个清晰的部分。
"""
messages.append(prompt_pt)
r = model.generate_content(messages).text
print(r)
# Out:
# 作为一位专业大厨，我将为您呈现一份兼顾风味、口感与色泽的“可乐鸡翅”食谱。此食谱经过精心挑选与优化，旨在让您在家也能烹饪出餐厅级别的美味。
#
# ---
#
# ### **可乐鸡翅烹饪方案分析与选择**
#
# 在烹制可乐鸡翅时，有几个关键步骤和配料组合会影响最终出品的风味和外观。我将为您分析三种常见方案，并最终选择一个最佳方案进行详细阐述。
#
# #### **方案一：经典速成法（不焯水，重煎炒）**
#
# *   **关键方法：** 鸡翅洗净后直接用调料（生抽、料酒、姜片）腌制，然后下锅煎至两面金黄，再加入可乐及其他调料炖煮收汁。
# *   **优点：**
#     *   **耗时短：** 省去了焯水环节，整体烹饪时间较短。
#     *   **风味浓郁：** 直接煎炒能让鸡翅表面产生美拉德反应，带来更深层次的焦香风味。
#     *   **操作相对简单：** 步骤较少。
# *   **缺点：**
#     *   **口感略腥：** 未焯水的鸡翅，若处理不当，内部血水和杂质可能导致腥味残留。
#     *   **汤汁不净：** 炖煮过程中可能产生较多浮沫，影响汤汁清澈度。
#     *   **肉质偏硬：** 缺少焯水预处理，鸡翅肉质可能不够软嫩。
#
# #### **方案二：极致软嫩入味法（焯水+充分腌制+慢炖）**
#
# *   **关键方法：** 鸡翅先焯水去除血沫和腥味，然后用生抽、料酒、姜蒜等充分腌制入味。接着将鸡翅煎至金黄，再加入可乐、生抽、老抽、香料（八角、干辣椒）等，小火慢炖至软烂，最后大火收汁。
# *   **优点：**
#     *   **口感软嫩：** 焯水和慢炖使鸡翅肉质极其软嫩，骨肉易分离。
#     *   **味道纯正：** 焯水彻底去除腥味，香料的加入使风味更富有层次。
#     *   **色泽红亮：** 老抽上色与可乐糖色完美结合，成品色泽诱人。
#     *   **汤汁醇厚：** 经过长时间炖煮，汤汁浓郁，更易挂在鸡翅上。
# *   **缺点：**
#     *   **耗时较长：** 焯水、腌制和慢炖都增加了整体烹饪时间。
#     *   **步骤较多：** 相较于速成法，操作略显复杂。
#
# #### **方案三：省力焖煮法（腌制后直接焖煮）**
#
# *   **关键方法：** 鸡翅洗净划几刀，直接用生抽、料酒、姜蒜腌制，然后与可乐、少量水、香料等一同放入锅中，直接开火焖煮至熟透收汁。不进行煎炒或焯水。
# *   **优点：**
#     *   **操作最简便：** 几乎没有额外的烹饪技巧要求，适合厨房新手。
#     *   **无需看管：** 一锅焖煮，相对省心。
# *   **缺点：**
#     *   **风味欠缺：** 缺乏煎炒带来的焦香，味道层次感不足。
#     *   **色泽平淡：** 没有经过煎炒上色，颜色可能不够红亮诱人。
#     *   **腥味不易去除：** 未焯水且未充分煎炒，腥味可能成为问题。
#
# #### **最佳方案选择：**
#
# 综合考虑风味、口感、色泽和专业厨师的出品标准，我强烈推荐**“方案二：极致软嫩入味法（焯水+充分腌制+慢炖）”**。尽管耗时略长、步骤稍多，但它能确保可乐鸡翅达到“甜咸适中，鸡翅软嫩，色泽红亮”的最高境界，呈现出最令人满意的效果。
#
# ---
#
# ### **可乐鸡翅 完整食谱**
#
# **菜肴名称：** 可乐鸡翅
#
# **风味要求：** 甜咸适中，鸡翅软嫩，色泽红亮
#
# ---
#
# #### **主食材：**
#
# *   鸡翅中：约10-12个 (约500克)
#
# #### **配料：**
#
# *   **【腌制用】**
#     *   生抽：2汤匙 (30毫升)
#     *   料酒：1汤匙 (15毫升)
#     *   姜片：3-4片
#     *   白胡椒粉：少许 (约1/4茶匙，可选)
# *   **【焯水用】**
#     *   姜片：2-3片
#     *   料酒：1汤匙 (15毫升)
#     *   葱段：2段 (葱白部分)
# *   **【烹饪用】**
#     *   可乐：1罐 (约330毫升)
#     *   生抽：3汤匙 (45毫升)
#     *   老抽：1汤匙 (15毫升) (用于上色，可根据喜好调整)
#     *   冰糖：15-20克 (可选，可根据可乐甜度和个人口味调整)
#     *   姜：4-5片
#     *   蒜：3-4瓣 (拍扁)
#     *   葱：1段 (葱白切段，葱绿切葱花备用)
#     *   八角：1-2颗 (可选，增加复合香气)
#     *   干辣椒：2-3个 (可选，增加微辣风味)
#     *   食用油：适量 (约3汤匙)
#     *   盐：适量 (收汁前根据口味调整)
#
# #### **步骤：**
#
# 1.  **鸡翅初处理与焯水：**
#     *   将鸡翅中洗净，沥干水分。为方便入味和受热均匀，可在鸡翅两面用刀划2-3刀，深度至骨，但不要切断。
#     *   取一锅，加入足量冷水，放入鸡翅中、2-3片姜片、1汤匙料酒和2段葱白。大火烧开，撇去浮沫。继续煮2-3分钟，待鸡翅变色并彻底去除血沫后捞出，用温水冲洗干净，沥干备用。此步骤是确保鸡翅无腥味、口感纯净的关键。
#
# 2.  **鸡翅腌制入味：**
#     *   将焯水后的鸡翅放入一个干净的碗中。加入2汤匙生抽、1汤匙料酒、3-4片姜片和少许白胡椒粉（如果使用）。用手抓匀，确保每个鸡翅都均匀沾上调料。静置腌制至少30分钟，若时间允许，冷藏腌制1小时以上风味更佳。
#
# 3.  **爆香与煎炒：**
#     *   炒锅烧热，加入适量食用油。待油温七成热时，放入4-5片姜片、拍扁的3-4瓣蒜、1段葱白、1-2颗八角（如果使用）和2-3个干辣椒（如果使用）。小火煸炒出香味。
#     *   将腌制好的鸡翅（挑出姜片）放入锅中，转中大火，将鸡翅煎至两面金黄。煎炒不仅能锁住鸡翅的水分，还能为后续上色打下基础，并增添焦香风味。
#
# 4.  **加入可乐与调味：**
#     *   待鸡翅煎至金黄后，倒入一罐可乐。接着加入3汤匙生抽和1汤匙老抽（老抽是上色的关键，能让鸡翅呈现红亮诱人的色泽）。如果使用冰糖，此时一同加入。
#     *   大火烧开，用锅铲轻轻翻动，让鸡翅均匀沾上汤汁。
#
# 5.  **慢炖收汁：**
#     *   汤汁烧开后转小火，盖上锅盖，焖煮约15-20分钟，或直至鸡翅软烂入味。期间可偶尔翻动，防止粘锅。
#     *   开盖，转大火将汤汁收浓。这一步是使汤汁挂在鸡翅上，形成浓郁光泽的关键。尝一下味道，如果觉得不够咸，可以适量加一点盐进行调整。当汤汁变得浓稠，能均匀包裹在鸡翅上时，即可关火。
#
# 6.  **装盘享用：**
#     *   将烹制好的可乐鸡翅盛出装盘，撒上切好的葱花点缀。趁热享用，感受那甜咸交织、软嫩多汁的美味！
#
# ---
#
# **厨师小贴士：**
#
# *   **可乐选择：** 建议使用原味可乐，不要用无糖或健怡可乐，它们的甜度不足且口感有差异。
# *   **火候掌控：** 煎鸡翅时火候不宜过小，以免出水；收汁时火候不宜过大，以免烧焦。
# *   **口味调整：** 可乐本身有甜度，冰糖是可选的，初次烹饪可先少放或不放，收汁前根据个人口味再调整。
# *   **提前腌制：** 腌制时间越长，鸡翅越入味，建议至少提前一小时腌制。
#
# 祝您烹饪愉快，享受这道经典的家庭美味！
